# %%
import random

your_move = 'wrong'

deck = [2,3,4,5,6,7,8,9]
random_hand = 2
random_card = 1
starting_hand = random.sample(deck, random_hand)
hit_card = random.sample(deck, random_card)

first_card = starting_hand[0]
second_card = starting_hand[1]

def display_game():
    
    a = first_card
    b = second_card
    your_move = 'wrong'
    player_hand = a,b
    hit_card = random.sample(deck, random_card)
    total = sum(player_hand)
    
    while your_move:
        
        
        print("Welcome to BlackJack! Here are your cards: ")
        print(player_hand)
        
        
        if total == 21:
            print("BLACKJACK---YOU WIN!")
            break
            
        elif total >=22 and 11 not in player_hand:
            your_move = ['Y','N']
            print("BUST---YOU LOSE!")
            
            while your_move not in ['Y','N']:
                your_move= input("Play again?: ")
                your_move = your_move.upper()
                
                if your_move not in ['Y','N']:
                    your_move= print("Please choose (Y) or (N).")
                    
            if your_move == 'Y':
                display_game()
            else:  
                print("Thanks for playing.")
            
            break
        
            
        elif player_hand[0] == 11 and player_hand[1:] != 11: 
            your_move = ['ONE','ELEVEN']
            your_move = input("Would you like a 'One' or an 'Eleven'?: ")
            your_move = your_move.upper()
            
            while your_move not in ['ONE','ELEVEN']:
                your_move= input("You can only pick (one) or (eleven): ")
                your_move= your_move.upper()
                
                if your_move not in ['ONE', 'ELEVEN']:
                    print("That is neither a one or an eleven....try again.")
            
            if your_move == 'ONE':
                ## have player hand updated with new SUM
                
                player_hand.pop(0)
                player_hand.append(1)
                return player_hand
                
            if your_move == 'ELEVEN':
                ## have player hand updated with new SUM
                
                player_hand.pop(0)
                player_hand.append(11)
                return player_hand
            
        elif player_hand[0] == 11 and player_hand[1] == 11:
            two_aces = True
            your_move = ['ONE','ELEVEN']
            
            while two_aces:
                for i in player_hand[0]:
                    your_move = input("Would you like a 'One' or an 'Eleven'?: ")
                    your_move = your_move.upper()
            
                    while your_move not in ['ONE','ELEVEN']:
                        your_move= input("You can only pick (one) or (eleven): ")
                        your_move= your_move.upper()
                
                        if your_move not in ['ONE', 'ELEVEN']:
                            print("That is neither a one or an eleven....try again.")
            
                        if your_move == 'ONE' or 'ELEVEN':
                    ## have player hand updated with new SUM
                
                            player_hand.pop(0)
                            player_hand.append(1)
                            
                            return player_hand
                
                        if your_move == 'ELEVEN':
                    ## have player hand updated with new SUM
                
                            player_hand.pop(0)
                            player_hand.append(11)
                            return player_hand
            
                for i in player_hand[1]:
                    your_move = input("Would you like a 'One' or an 'Eleven'?: ")
                    your_move = your_move.upper()
                
                    while your_move not in ['ONE','ELEVEN']:
                        your_move= input("You can only pick (one) or (eleven): ")
                    
                        if your_move not in ['ONE', 'ELEVEN']:
                            print("That is neither a one or an eleven....try again.")
            
                        if your_move == 'ONE':
                    ## have player hand updated with new SUM
                            player_hand.pop(0)
                            player_hand.append(1)
                            return player_hand
                    
                        if your_move == 'ELEVEN':
                    ## have player hand updated with new SUM
                            player_hand.pop(0)
                            player_hand.append(11)
                            return player_hand
                
                        else:
                            return False
                        break
                    break
                break
        else:
            print("You haven't hit 21, yet")
        
            
        if your_move:
            your_move = ['HIT','STAY','DOUBLE DOWN']
            your_move = input("What would you like to do?: ").upper()
            
            while your_move not in ['HIT','STAY','DOUBLE DOWN']:
                your_move= input("Please make a valid choice (Hit, Stay, Double Down): ").upper()
                
                if your_move not in ['HIT','STAY','DOUBLE DOWN']:
                    print("I don't understand that, try again...")
            else:
                if your_move == 'HIT':
                        player_hand = list(player_hand)
                        hit_card = list(hit_card)
                        new_hand = player_hand + hit_card
                        print(new_hand)
                        
                        if sum(new_hand) >=22 and sum(new_hand) !=21:
                            print("BUST")
                        
                            
                        elif sum(new_hand) < 22 and sum(new_hand) != 21:
                            your_move = ['HIT','STAY',]
                            your_move = input("What would you like to do?: ").upper()
                        
                            while your_move not in ['HIT','STAY',]:
                                your_move= input("Please make a valid choice (Hit, Stay, Double Down): ").upper()
                    
                                if your_move not in ['HIT','STAY',]:
                                    print("I don't understand that, try again...")
                            else:
                                
                                if your_move == 'HIT':
                                    new_hand = new_hand + hit_card
                                    print(new_hand)
                            
                             
                                if your_move == 'STAY':
                                    
                                
                                    if sum(new_hand) <= 21:
                                        total = sum(new_hand)
                                        print(total)
                                    else:
                                        pass
                                else:
                                    break
                        else:
                            ## YOU LOSE, attempt to restart game##
                            print("BUST")
                else:
                    print("write more code")
                
                    
                    
            
        else:
            print("write more code")

# %%
display_game()
# Out:
# Welcome to BlackJack! Here are your cards:
# (8, 9)
# You haven't hit 21, yet
# What would you like to do?: hit
# [8, 9, 2]
# What would you like to do?: hit
# [8, 9, 2, 2]

# %%
def player_choice():
    
    your_move = 'wrong'
    
    while your_move not in ['HIT ME','STAY','DOUBLE DOWN']:
        
        ####insert f string literal below to display player's show card(s)####
        
        your_move= input(f"Dealer- You have {face_card} showing, {total} Would you like to (Hit, Stay, Double Down) ?: ".format(face_card, total))
        your_move = your_move.upper()
        
        if your_move not in ['HIT','STAY','DOUBLE DOWN']:
            print("Whoa! That's not how you play Blackjack.")
            
    return your_move

# %%
player_choice()

# %%
def gameon_choice():
    
    choice = 'wrong'
    
     
    while choice not in ['Y', 'N']:
        
        choice= input("Keep playing? (Y or N): ")
        choice = choice.upper()
        
        if choice not in ['Y', 'N']:
            print("Sorry, I didn't understand that. Please choose (Y or N): ")
            
    if choice == "Y":
        return True
    else:
        return False

# %%
game_on = True


while game_on:
    
    display_game()
    
    position = position_choice()
    
    game_list = replacement_choice(game_list,position)
    
    display_game(game_list)
    
    game_on = gameon_choice()

# %%
s

# %%
or player_hand[1] == 11:
